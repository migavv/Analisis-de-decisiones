# %% [markdown]
# # Importar Librerías

# %%
#Uso de datos
import pandas as pd
import numpy as np
import yfinance as yf

#Gráficos
import matplotlib.pyplot as plt

#Algoritmos evolutivos
import random
from deap import base, creator, tools, algorithms

#Advertencias
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Uso de yfinance

# %%
PG = yf.download('PG', start = '2019-05-01', end = '2023-10-24')
PG
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-01  106.150002  106.389999  104.809998  104.930000   93.844574
# 2019-05-02  105.199997  105.760002  105.050003  105.559998   94.408005
# 2019-05-03  105.989998  106.410004  105.580002  106.080002   94.873077
# 2019-05-06  105.120003  105.820000  105.040001  105.680000   94.515320
# 2019-05-07  105.029999  105.580002  104.099998  104.699997   93.638878
# ...                ...         ...         ...         ...         ...
# 2023-10-17  146.110001  146.820007  145.240005  146.259995  145.342636
# 2023-10-18  150.059998  151.300003  148.770004  150.029999  149.089005
# 2023-10-19  149.610001  150.279999  147.179993  148.250000  148.250000
# 2023-10-20  149.050003  149.880005  147.919998  148.050003  148.050003
# 2023-10-23  147.860001  149.500000  147.559998  148.149994  148.149994
#
#               Volume
# Date
# 2019-05-01   6733800
# 2019-05-02   6270300
# 2019-05-03   4793400
# 2019-05-06   4890400
# 2019-05-07   6021700
# ...              ...
# 2023-10-17   6160100
# 2023-10-18  10508500
# 2023-10-19   8146000
# 2023-10-20   7283900
# 2023-10-23   5981800
#
# [1129 rows x 6 columns]

# %%
tickers = ['PG', 'GE', 'TSLA', 'AMZN', '^GSPC']
datos = pd.DataFrame()

for t in tickers:
    datos[t] = yf.download(t, start = '2019-01-01')['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
datos.plot(figsize = (20, 8))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
datos.drop('^GSPC', axis = 1).plot(figsize = (20, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
datos = datos.drop('^GSPC', axis = 1)
datos
# Out:
#                     PG          GE        TSLA        AMZN
# Date
# 2019-01-02   80.428238   47.434509   20.674667   76.956497
# 2019-01-03   79.864319   47.493435   20.024000   75.014000
# 2019-01-04   81.494370   48.495163   21.179333   78.769501
# 2019-01-07   81.168381   51.500332   22.330667   81.475502
# 2019-01-08   81.467949   50.439682   22.356667   82.829002
# ...                ...         ...         ...         ...
# 2023-10-18  149.089005  107.570000  242.679993  128.130005
# 2023-10-19  148.250000  106.949997  220.110001  128.399994
# 2023-10-20  148.050003  106.080002  211.990005  125.169998
# 2023-10-23  148.149994  106.690002  212.080002  126.559998
# 2023-10-24  149.899994  113.620003  216.520004  128.559998
#
# [1212 rows x 4 columns]

# %% [markdown]
# # Retorno simple

# %%
retorno_simple = datos.pct_change().dropna()
retorno_simple.plot(figsize = (20, 8))
plt.show()

# %% [markdown]
# # Retorno logarítmico

# %%
retorno_logaritmico = np.log(datos/datos.shift(1))
retorno_logaritmico.plot(figsize = (20, 8))
plt.show()

# %% [markdown]
# # Implementación algoritmo evolutivo

# %%
#Función de adaptabilidad
def evaluar_portafolio(individuo, ret_simple, ret_log):
    pesos = np.array(individuo) / np.sum(individuo)
    retorno_portafolio = np.dot((ret_simple.mean() * 250), pesos)
    riesgo_portafolio = np.sqrt(np.dot(pesos.T, np.dot((ret_log.cov() * 250), pesos)))
    return retorno_portafolio, riesgo_portafolio,

# %%
#Declarar el contenedor de los operadores genéticos
toolbox = base.Toolbox()

# %%
#Crear la clase función de adaptabilidad y la clase individuo
creator.create('FitnessMulti', base.Fitness, weights = (1.0, -1.0,))
creator.create('Individual', list, fitness = creator.FitnessMulti)
