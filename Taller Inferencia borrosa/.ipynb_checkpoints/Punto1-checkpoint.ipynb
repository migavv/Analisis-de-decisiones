# %%
# !pip install plotly
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import plotly.express as px
import skfuzzy
from skfuzzy import control as ctrl
import warnings
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Declarar universos de discurso

# %%
#Reclamaciones de clientes
reclamaciones = ctrl.Antecedent(np.arange(3,25, 1),"reclamaciones")
#Nivel de servicio
servicio = ctrl.Antecedent(np.arange(25,86,1), "servicio")
#Frecuencia
frecuencia = ctrl.Consequent(np.arange(5,52,1), "frecuencia")
#Posibilidad de retiro de cliente
retiro = ctrl.Consequent(np.arange(10,100,1), "retiro")

# %% [markdown]
# # 2. Fuzzificar variables

# %%
#Reclamaciones de clientes
reclamaciones['pocas'] = skfuzzy.trapmf(reclamaciones.universe,[3,3,6,10])
reclamaciones['moderadas'] = skfuzzy.trapmf(reclamaciones.universe, [8,10,15,18])
reclamaciones['muchas'] = skfuzzy.trapmf(reclamaciones.universe, [16,18,25,25])
reclamaciones.view()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Nivel de servicio
servicio["bajo"] = skfuzzy.trapmf(servicio.universe, [25,25,35,45])
servicio["medio"] = skfuzzy.trapmf(servicio.universe, [40,45,65,70])
servicio["alto"] = skfuzzy.trapmf(servicio.universe, [60,70,86,86])

servicio.view()
plt.show()

# %%
#Frecuencia de visita
frecuencia["baja"] = skfuzzy.trapmf(frecuencia.universe, [5,5,15,25])
frecuencia["media"] = skfuzzy.trapmf(frecuencia.universe, [20,25,35,40])
frecuencia["alta"] = skfuzzy.trapmf(frecuencia.universe, [35,40,50,52])

frecuencia.view()
plt.show()

# %%
#Probabilidad de retiro de cliente
retiro["baja"] = skfuzzy.trapmf(retiro.universe, [10,10,30,40])
retiro["media"] = skfuzzy.trapmf(retiro.universe, [35,40,60,65])
retiro["alta"] = skfuzzy.trapmf(retiro.universe, [60,65,90,100])

retiro.view()
plt.show()

# %% [markdown]
# # 3. Crear base de conocimiento
